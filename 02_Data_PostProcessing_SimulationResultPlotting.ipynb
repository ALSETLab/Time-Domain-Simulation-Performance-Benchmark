# %% [markdown]
# Data Postprocessing - Verification of Simulation Results
# ==============
#
# **Authors:** Sergio A. Dorado-Rojas (sergio.dorado.rojas@gmail.com), Manuel Navarro Catalan (manosnavarro@gmail.com), Marcelo de Castro Fernandes (decasm3@rpi.edu) and Luigi Vanfretti (luigi.vanfretti@gmail.com)

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from modelicares import SimRes
from plot_sim_results import*

# %%
experiments = ['initialization', 'line_opening', 'bus_faults']
solvers = ['dassl', 'euler', 'trapezoid', 'rungekutta']

n_plot = 1

for experiment in experiments:
    for solver in solvers:
        fig_name = "Fig{r:02d}_SimResults_{e}_{s}".format(r = n_plot, e = experiment, s = solver)
        plot_sim_results(solver, experiment, fig_name)
        n_plot += 1
# Out:
# ================================
#      dassl - initialization
# ================================
# MSE B2 = 2.992545552690425e-11
# MSE B4 = 4.6402240179806243e-11
# ================================
# ================================
#      euler - initialization
# ================================
# MSE B2 = 1.2894832984667679e-11
# MSE B4 = 3.7950860875841335e-11
# ================================
# ================================
#    trapezoid - initialization
# ================================
# MSE B2 = 1.2852860911130187e-11
# MSE B4 = 3.7828562532211583e-11
# ================================
# ================================
#   rungekutta - initialization
# ================================
# MSE B2 = 1.2853923605088936e-11
# MSE B4 = 3.782857165656188e-11
# ================================
# ================================
#       dassl - line_opening
# ================================
# MSE B2 = 1.172620680430736e-08
# MSE B4 = 1.1266890195032593e-07
# ================================
# ================================
#       euler - line_opening
# ================================
# MSE B2 = 2.359890151160389e-10
# MSE B4 = 3.247042560508107e-09
# ================================
# ================================
#     trapezoid - line_opening
# ================================
# MSE B2 = 2.358261425682039e-10
# MSE B4 = 3.2473116365287e-09
# ================================
# ================================
#    rungekutta - line_opening
# ================================
# MSE B2 = 2.357903331905251e-10
# MSE B4 = 3.2472817646073025e-09
# ================================
# ================================
#        dassl - bus_faults
# ================================
# MSE B4 = 0.0026779198064096395
# MSE B1 = 0.0069787438954042064
# ================================
# ================================
#        euler - bus_faults
# ================================
# MSE B4 = 0.00030065609822479944
# MSE B1 = 0.0028745205093293736
# ================================
# ================================
#      trapezoid - bus_faults
# ================================
# MSE B4 = 0.00024352431957691447
# MSE B1 = 0.002105963149969513
# ================================
# ================================
#     rungekutta - bus_faults
# ================================
# MSE B4 = 0.00024029854829446979
# MSE B1 = 0.0020433425076225595
# ================================
