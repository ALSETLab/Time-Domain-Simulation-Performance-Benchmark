# %% [markdown]
# Data Postprocessing - Verification of Simulation Results
# ==============
#
# **Authors:** Sergio A. Dorado-Rojas (sergio.dorado.rojas@gmail.com), Manuel Navarro Catalan (manosnavarro@gmail.com), Marcelo de Castro Fernandes (decasm3@rpi.edu) and Luigi Vanfretti (luigi.vanfretti@gmail.com)

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from modelicares import SimRes
from plot_sim_results import*

# %%
experiments = ['initialization', 'line_opening', 'bus_faults']
solvers = ['dassl', 'euler', 'trapezoid', 'rungekutta']

n_plot = 1

for experiment in experiments:
    for solver in solvers:
        fig_name = "Fig{r:02d}_SimResults_{e}_{s}".format(r = n_plot, e = experiment, s = solver)
        plot_sim_results(solver, experiment, fig_name)
        n_plot += 1
# Out:
# ...
#      dassl - initialization
# ...
# MSE B2 = 3.0011448507434655e-11
# MSE B4 = 4.6482681091565954e-11
# ...
# /home/dorads/Documents/Google_Drive/03_Papers/01_Conference_Papers/04_2019_AmericanModelicaConference_II/05_SimulationCode/Time-Domain-Simulation-Performance-Benchmark/plot_sim_results.py:81: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.tight_layout()
# /home/dorads/Documents/Google_Drive/03_Papers/01_Conference_Papers/04_2019_AmericanModelicaConference_II/05_SimulationCode/Time-Domain-Simulation-Performance-Benchmark/plot_sim_results.py:85: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.savefig('Figs/01_Tool_Result_Analysis/{}.png'.format(fig_name), dpi = 300)
# ...
#      euler - initialization
# ...
# MSE B2 = 1.2894832983843917e-11
# MSE B4 = 3.795086087531114e-11
# ...
#    trapezoid - initialization
# ...
# MSE B2 = 1.2852860911167237e-11
# MSE B4 = 3.7828562532240373e-11
# ...
#   rungekutta - initialization
# ...
